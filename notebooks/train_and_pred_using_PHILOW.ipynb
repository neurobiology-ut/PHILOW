# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/neurobiology-ut/Philis/blob/feature/add_train_and_pred_notebooks/notebooks/train.ipynb)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os

import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers import Adam , RMSprop
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint , EarlyStopping , CSVLogger
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2

from tqdm.notebook import tqdm
import pandas as pd

# %%
def normalize_x(image):
    return image / 127.5 - 1


def normalize_y(image):
    return image / 255


def denormalize_y(image):
    return image * 255

# %%
def load_X_gray(folder_path):
    
    image_files = []       
    for file in os.listdir(folder_path):
        base, ext = os.path.splitext(file)
        if ext == '.png':
            image_files.append(file)
        else :
            pass
        
    image_files.sort()
    
    img = cv2.imread(folder_path + os.sep + image_files[0], cv2.IMREAD_GRAYSCALE)
    
    images = np.zeros((len(image_files), img.shape[0], img.shape[1], 1), np.float32)
    for i, image_file in tqdm(enumerate(image_files)):
        image = cv2.imread(folder_path + os.sep + image_file, cv2.IMREAD_GRAYSCALE)
        image = image[:, :, np.newaxis]
        images[i] = normalize_x(image)
    
    print(images.shape)
    
    return images, image_files


def load_Y_gray(folder_path, thresh = None , normalize = False):
    
    image_files = []
    for file in os.listdir(folder_path):
        base, ext = os.path.splitext(file)
        if ext == '.png':
            image_files.append(file)
        else:
            pass
        
    image_files.sort()
    
    img = cv2.imread(folder_path + os.sep + image_files[0], cv2.IMREAD_GRAYSCALE)
    
    images = np.zeros((len(image_files), img.shape[0], img.shape[1], 1) ,np.float32)
    
    for i , image_file in tqdm(enumerate(image_files)):
        image = cv2.imread(folder_path + os.sep + image_file, cv2.IMREAD_GRAYSCALE)
        if thresh:
            ret , image = cv2.threshold(image , thresh , 255 , cv2.THRESH_BINARY)
        image = image[:, :, np.newaxis]
        if normalize:
            images[i] = normalize_y(image)
        else:
            images[i] = image
            
    print(images.shape)
    
    return images, image_files

# %%
def select_train_data(dataframe, ori_imgs, label_imgs, ori_filenames, label_filenames):

  train_img_names = list()
  for node in dataframe.itertuples():
    if node.train == "Checked":
      train_img_names.append(node.filename)

  train_ori_imgs = list()
  train_label_imgs = list()
  for ori_img, label_img, train_filename in zip(ori_imgs, label_imgs, ori_filenames):
    if train_filename in train_img_names:
      train_ori_imgs.append(ori_img)
      train_label_imgs.append(label_img)

  return np.array(train_ori_imgs),  np.array(train_label_imgs)

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score


def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss


def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss


def weighted_dice_coeff(y_true, y_pred, weight):
    smooth = 1.
    w, m1, m2 = weight * weight, y_true, y_pred
    intersection = (m1 * m2)
    score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
    return score


def weighted_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd number
    if K.int_shape(y_pred)[1] == 128:
        kernel_size = 11
    elif K.int_shape(y_pred)[1] == 256:
        kernel_size = 21
    elif K.int_shape(y_pred)[1] == 512:
        kernel_size = 21
    elif K.int_shape(y_pred)[1] == 1024:
        kernel_size = 41
    else:
        raise ValueError('Unexpected image size')
    averaged_mask = K.pool2d(
        y_true, pool_size=(kernel_size, kernel_size), strides=(1, 1), padding='same', pool_mode='avg')
    border = K.cast(K.greater(averaged_mask, 0.005), 'float32') * K.cast(K.less(averaged_mask, 0.995), 'float32')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight += border * 2
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = 1 - weighted_dice_coeff(y_true, y_pred, weight)
    return loss


def weighted_bce_loss(y_true, y_pred, weight):
    # avoiding overflow
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))

    # https://www.tensorflow.org/api_docs/python/tf/nn/weighted_cross_entropy_with_logits
    loss = (1. - y_true) * logit_y_pred + (1. + (weight - 1.) * y_true) * \
                                          (K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)


def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd number
    if K.int_shape(y_pred)[1] == 128:
        kernel_size = 11
    elif K.int_shape(y_pred)[1] == 256:
        kernel_size = 21
    elif K.int_shape(y_pred)[1] == 512:
        kernel_size = 21
    elif K.int_shape(y_pred)[1] == 1024:
        kernel_size = 41
    else:
        raise ValueError('Unexpected image size')
    averaged_mask = K.pool2d(
        y_true, pool_size=(kernel_size, kernel_size), strides=(1, 1), padding='same', pool_mode='avg')
    border = K.cast(K.greater(averaged_mask, 0.005), 'float32') * K.cast(K.less(averaged_mask, 0.995), 'float32')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight += border * 2
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = weighted_bce_loss(y_true, y_pred, weight) + (1 - weighted_dice_coeff(y_true, y_pred, weight))
    return loss

# %%
def standard_uint(input_tensor, nb_filter):
    
    x = Conv2D(nb_filter, (3, 3), padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(nb_filter, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x


def get_nested_unet(input_shape=(512, 512, 1), num_classes=3, deep_supervision = False):
    
    with tf.device('/gpu:0'):
        
        inputs = Input(shape = input_shape)
        
        # 512
        conv1_1 = standard_uint(inputs, nb_filter = 16)
        pool1 = MaxPooling2D((2, 2), strides = (2, 2))(conv1_1)
        
        #256
        conv2_1 = standard_uint(pool1, nb_filter = 32)
        pool2 = MaxPooling2D((2, 2), strides = (2, 2))(conv2_1)
        
        up1_2 = Conv2DTranspose(16, (2, 2), strides = (2, 2), padding = 'same')(conv2_1)
        conv1_2 = concatenate([up1_2, conv1_1], axis = 3)
        conv1_2 = standard_uint(conv1_2, nb_filter = 16)
        
        #128
        conv3_1 = standard_uint(pool2, nb_filter = 64)
        pool3 = MaxPooling2D((2, 2), strides = (2, 2))(conv3_1)
        
        up2_2 = Conv2DTranspose(32, (2, 2), strides = (2, 2), padding = 'same')(conv3_1)
        conv2_2 = concatenate([up2_2, conv2_1], axis = 3)
        conv2_2 = standard_uint(conv2_2, nb_filter = 32)
        
        up1_3 = Conv2DTranspose(16, (2, 2), strides = (2, 2), padding = 'same')(conv2_2)
        conv1_3 = concatenate([up1_3, conv1_1, conv1_2], axis = 3)
        conv1_3 = standard_uint(conv1_3, nb_filter = 16)
        
        # 64
        conv4_1 = standard_uint(pool3, nb_filter = 128)
        pool4 = MaxPooling2D((2, 2), strides = (2, 2))(conv4_1)      
        
        up3_2 = Conv2DTranspose(64, (2, 2), strides = (2, 2), padding = 'same')(conv4_1)
        conv3_2 = concatenate([up3_2, conv3_1], axis = 3)
        conv3_2 = standard_uint(conv3_2, nb_filter = 64)    
        
        up2_3 = Conv2DTranspose(32, (2, 2), strides = (2, 2), padding = 'same')(conv3_2)
        conv2_3 = concatenate([up2_3, conv2_1, conv2_2], axis = 3)
        conv2_3 = standard_uint(conv2_3, nb_filter = 32)        
        
        up1_4 = Conv2DTranspose(16, (2, 2), strides = (2, 2), padding = 'same')(conv2_3)
        conv1_4 = concatenate([up1_4, conv1_2, conv1_3], axis = 3)
        conv1_4 = standard_uint(conv1_4, nb_filter = 16)       
        
        # 32
        conv5_1 = standard_uint(pool4, nb_filter = 256)    
        
        up4_2 = Conv2DTranspose(128, (2, 2), strides = (2, 2), padding = 'same')(conv5_1)
        conv4_2 = concatenate([up4_2, conv4_1], axis = 3)
        conv4_2 = standard_uint(conv4_2, nb_filter = 128)  
        
        up3_3 = Conv2DTranspose(64, (2, 2), strides = (2, 2), padding = 'same')(conv4_2)
        conv3_3 = concatenate([up3_3, conv3_1, conv3_2], axis = 3)
        conv3_3 = standard_uint(conv3_3, nb_filter = 64)
        
        up2_4 = Conv2DTranspose(32, (2, 2), strides = (2, 2), padding = 'same')(conv3_3)
        conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], axis = 3)
        conv2_4 = standard_uint(conv2_4, nb_filter = 32)
        
        up1_5 = Conv2DTranspose(16, (2, 2), strides = (2, 2), padding = 'same')(conv2_4)
        conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], axis = 3)
        conv1_5 = standard_uint(conv1_5, nb_filter = 16)
        
        nested_output_1 = Conv2D(num_classes, (1, 1), activation = 'sigmoid')(conv1_2)
        nested_output_2 = Conv2D(num_classes, (1, 1), activation = 'sigmoid')(conv1_3)
        nested_output_3 = Conv2D(num_classes, (1, 1), activation = 'sigmoid')(conv1_4)
        nested_output_4 = Conv2D(num_classes, (1, 1), activation = 'sigmoid')(conv1_5)
        
        if deep_supervision:
            model = Model(inputs = inputs, outputs = [nested_output_1, nested_output_2, nested_output_3, nested_output_4]) 
        else:
            model = Model(inputs = inputs, outputs = [nested_output_4])
            
        model.compile(optimizer=RMSprop(lr=0.0001), loss=bce_dice_loss, metrics=[dice_coeff])
        
        return model

# %%
def train_unet(X_train,Y_train, csv_path, model_path ,input_shape=(512, 512, 1), num_classes=1):
    Y_train = Y_train
    X_train = X_train

    data_gen_args = dict(
        rotation_range=90.,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True
    )
    image_datagen = ImageDataGenerator(**data_gen_args)
    mask_datagen = ImageDataGenerator(**data_gen_args)

    # Provide the same seed and keyword arguments to the fit and flow methods
    seed = 1
    image_datagen.fit(X_train, augment=True, seed=seed)
    mask_datagen.fit(Y_train, augment=True, seed=seed)

    image_generator = image_datagen.flow(X_train, seed=seed, batch_size=8)
    mask_generator = mask_datagen.flow(Y_train, seed=seed, batch_size=8)

    # combine generators into one which yields image and masks
    train_generator = (pair for pair in zip(image_generator, mask_generator))

    model = get_nested_unet(input_shape=input_shape, num_classes=num_classes)

    BATCH_SIZE = 4
    NUM_EPOCH = 400
    
    callbacks = []
    from tensorflow.keras.callbacks import CSVLogger
    callbacks.append(CSVLogger(csv_path))
    history = model.fit_generator(train_generator,steps_per_epoch=32, epochs=NUM_EPOCH, verbose=1, callbacks=callbacks)
    model.save_weights(model_path)

# %%
def predict(X_test, model_path, out_dir, input_shape=(512, 512, 1), num_classes=1):

    model = get_nested_unet(input_shape=input_shape, num_classes=num_classes)
    
    model.load_weights(model_path)
    BATCH_SIZE = 1
    Y_pred = model.predict(X_test, BATCH_SIZE)
    
    print(Y_pred.shape)
    os.makedirs(out_dir, exist_ok = True)
    
    if Y_pred.shape[3]!=1:
        num = Y_pred.shape[3]
        for n in range(num):
            os.makedirs(os.path.join(out_dir,str(n+1)), exist_ok=True)
        for i, y in enumerate(Y_pred):
            for n in range(num):
                cv2.imwrite(os.path.join(out_dir, str(n+1) , str(i).zfill(6) + '.png'), denormalize_y(y[:,:,n]))
        
    else:
        for i, y in enumerate(Y_pred):
            cv2.imwrite(os.path.join(out_dir , str(i).zfill(6) + '.png'), denormalize_y(y))

# %%
def make_mask_img(ori_img, mask_img):
    mask_img_rgb = np.zeros((mask_img.shape[0], mask_img.shape[1], 3), np.float32)
    mask_img_rgb[:,:,0] = mask_img[:,:,0]
    mask_img_rgb[:,:,2] = mask_img[:,:,0]
    masked_img = cv2.addWeighted(mask_img_rgb,0.5,cv2.cvtColor(ori_img+0.75, cv2.COLOR_GRAY2BGR),0.6,0)
    return masked_img

# %% [markdown]
# # train

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

gdd.download_file_from_google_drive(file_id='1qe5nuGhxxOCTWc0rE1Ecqk2aN2saiLv6',
                                    dest_path='./data.zip',
                                    unzip=True)
# Out:
# Downloading 1qe5nuGhxxOCTWc0rE1Ecqk2aN2saiLv6 into ./data.zip... Done.
# Unzipping...Done.

# %%
ori_imgs, ori_filenames = load_X_gray("./PHILOW_demo_data/ori")
label_imgs, label_filenames = load_Y_gray("./PHILOW_demo_data/label", normalize=False)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# (200, 512, 512, 1)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# (200, 512, 512, 1)

# %%
train_csv = pd.read_csv("./PHILOW_demo_data/label/_train0.csv", index_col=0)

# %%
train_ori_imgs, train_label_imgs = select_train_data(
    dataframe = train_csv, 
    ori_imgs  = ori_imgs, 
    label_imgs = label_imgs, 
    ori_filenames = ori_filenames,
    label_filenames = label_filenames
  )

# %%
plt.figure(figsize=(15, 15))

plt.subplot(2, 2, 1)
plt.imshow(train_ori_imgs[4][:,:,0], "gray")

plt.subplot(2, 2, 2)
plt.imshow(train_label_imgs[4][:,:,0], "gray")

plt.subplot(2, 2, 3)
plt.imshow(train_ori_imgs[7][:,:,0], "gray")

plt.subplot(2, 2, 4)
plt.imshow(train_label_imgs[7][:,:,0], "gray")

# %%
train_unet(
    X_train = train_ori_imgs,
    Y_train = train_label_imgs, 
    csv_path = "train_log.csv", 
    model_path = "demo.hdf5", 
    input_shape = (512, 512, 1),
    num_classes = 1
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1
400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0437 - dice_coeff: 0.9712
# Epoch 120/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0497 - dice_coeff: 0.9678
# Epoch 121/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0437 - dice_coeff: 0.9723
# Epoch 122/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0429 - dice_coeff: 0.9728
# Epoch 123/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0460 - dice_coeff: 0.9708
# Epoch 124/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0458 - dice_coeff: 0.9721
# Epoch 125/400
# 32/32 [==============================] - 12s 372ms/step - loss: 0.0458 - dice_coeff: 0.9715
# Epoch 126/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0446 - dice_coeff: 0.9719
# Epoch 127/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0423 - dice_coeff: 0.9739
# Epoch 128/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0459 - dice_coeff: 0.9713
# Epoch 129/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0408 - dice_coeff: 0.9744
# Epoch 130/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0425 - dice_coeff: 0.9735
# Epoch 131/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0398 - dice_coeff: 0.9746
# Epoch 132/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0393 - dice_coeff: 0.9750
# Epoch 133/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0399 - dice_coeff: 0.9757
# Epoch 134/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0410 - dice_coeff: 0.9748
# Epoch 135/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0386 - dice_coeff: 0.9758
# Epoch 136/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0386 - dice_coeff: 0.9763
# Epoch 137/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0432 - dice_coeff: 0.9729
# Epoch 138/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0363 - dice_coeff: 0.9776
# Epoch 139/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0385 - dice_coeff: 0.9760
# Epoch 140/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0401 - dice_coeff: 0.9747
# Epoch 141/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0382 - dice_coeff: 0.9766
# Epoch 142/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0367 - dice_coeff: 0.9767
# Epoch 143/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0377 - dice_coeff: 0.9755
# Epoch 144/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0368 - dice_coeff: 0.9774
# Epoch 145/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0382 - dice_coeff: 0.9765
# Epoch 146/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0380 - dice_coeff: 0.9763
# Epoch 147/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0407 - dice_coeff: 0.9746
# Epoch 148/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0368 - dice_coeff: 0.9772
# Epoch 149/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0378 - dice_coeff: 0.9770
# Epoch 150/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0358 - dice_coeff: 0.9780
# Epoch 151/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0373 - dice_coeff: 0.9773
# Epoch 152/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0371 - dice_coeff: 0.9771
# Epoch 153/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0353 - dice_coeff: 0.9780
# Epoch 154/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0341 - dice_coeff: 0.9792
# Epoch 155/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0380 - dice_coeff: 0.9773
# Epoch 156/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0368 - dice_coeff: 0.9765
# Epoch 157/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0342 - dice_coeff: 0.9792
# Epoch 158/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0351 - dice_coeff: 0.9776
# Epoch 159/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0345 - dice_coeff: 0.9783
# Epoch 160/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0353 - dice_coeff: 0.9781
# Epoch 161/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0333 - dice_coeff: 0.9797
# Epoch 162/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0359 - dice_coeff: 0.9780
# Epoch 163/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0347 - dice_coeff: 0.9787
# Epoch 164/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0348 - dice_coeff: 0.9782
# Epoch 165/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0364 - dice_coeff: 0.9775
# Epoch 166/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0355 - dice_coeff: 0.9789
# Epoch 167/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0340 - dice_coeff: 0.9795
# Epoch 168/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0334 - dice_coeff: 0.9800
# Epoch 169/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0316 - dice_coeff: 0.9805
# Epoch 170/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0344 - dice_coeff: 0.9798
# Epoch 171/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0326 - dice_coeff: 0.9799
# Epoch 172/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0376 - dice_coeff: 0.9768
# Epoch 173/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0323 - dice_coeff: 0.9806
# Epoch 174/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0331 - dice_coeff: 0.9799
# Epoch 175/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0355 - dice_coeff: 0.9791
# Epoch 176/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0334 - dice_coeff: 0.9791
# Epoch 177/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0325 - dice_coeff: 0.9798
# Epoch 178/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0327 - dice_coeff: 0.9799
# Epoch 179/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0342 - dice_coeff: 0.9799
# Epoch 180/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0338 - dice_coeff: 0.9789
# Epoch 181/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0318 - dice_coeff: 0.9807
# Epoch 182/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0325 - dice_coeff: 0.9806
# Epoch 183/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0331 - dice_coeff: 0.9803
# Epoch 184/400
# 32/32 [==============================] - 12s 372ms/step - loss: 0.0332 - dice_coeff: 0.9787
# Epoch 185/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0314 - dice_coeff: 0.9811
# Epoch 186/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0348 - dice_coeff: 0.9788
# Epoch 187/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0327 - dice_coeff: 0.9801
# Epoch 188/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0311 - dice_coeff: 0.9808
# Epoch 189/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0318 - dice_coeff: 0.9798
# Epoch 190/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0317 - dice_coeff: 0.9810
# Epoch 191/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0309 - dice_coeff: 0.9809
# Epoch 192/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0320 - dice_coeff: 0.9809
# Epoch 193/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0328 - dice_coeff: 0.9801
# Epoch 194/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0293 - dice_coeff: 0.9821
# Epoch 195/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0333 - dice_coeff: 0.9786
# Epoch 196/400
# 32/32 [==============================] - 12s 372ms/step - loss: 0.0315 - dice_coeff: 0.9807
# Epoch 197/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0318 - dice_coeff: 0.9803
# Epoch 198/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0302 - dice_coeff: 0.9815
# Epoch 199/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0301 - dice_coeff: 0.9817
# Epoch 200/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0335 - dice_coeff: 0.9786
# Epoch 201/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0300 - dice_coeff: 0.9816
# Epoch 202/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0328 - dice_coeff: 0.9804
# Epoch 203/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0311 - dice_coeff: 0.9810
# Epoch 204/400
# 32/32 [==============================] - 12s 372ms/step - loss: 0.0305 - dice_coeff: 0.9815
# Epoch 205/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0308 - dice_coeff: 0.9813
# Epoch 206/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0298 - dice_coeff: 0.9817
# Epoch 207/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0305 - dice_coeff: 0.9815
# Epoch 208/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0324 - dice_coeff: 0.9807
# Epoch 209/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0297 - dice_coeff: 0.9820
# Epoch 210/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0317 - dice_coeff: 0.9813
# Epoch 211/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0299 - dice_coeff: 0.9821
# Epoch 212/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0307 - dice_coeff: 0.9810
# Epoch 213/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0315 - dice_coeff: 0.9807
# Epoch 214/400
# 32/32 [==============================] - 12s 372ms/step - loss: 0.0287 - dice_coeff: 0.9826
# Epoch 215/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0301 - dice_coeff: 0.9808
# Epoch 216/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0300 - dice_coeff: 0.9819
# Epoch 217/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0296 - dice_coeff: 0.9823
# Epoch 218/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0286 - dice_coeff: 0.9828
# Epoch 219/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0283 - dice_coeff: 0.9828
# Epoch 220/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0291 - dice_coeff: 0.9821
# Epoch 221/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0301 - dice_coeff: 0.9818
# Epoch 222/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0293 - dice_coeff: 0.9820
# Epoch 223/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0295 - dice_coeff: 0.9822
# Epoch 224/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0306 - dice_coeff: 0.9816
# Epoch 225/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0304 - dice_coeff: 0.9818
# Epoch 226/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0294 - dice_coeff: 0.9823
# Epoch 227/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0300 - dice_coeff: 0.9820
# Epoch 228/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0302 - dice_coeff: 0.9817
# Epoch 229/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0293 - dice_coeff: 0.9824
# Epoch 230/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0328 - dice_coeff: 0.9806
# Epoch 231/400
# 32/32 [==============================] - 12s 380ms/step - loss: 0.0305 - dice_coeff: 0.9812
# Epoch 232/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0297 - dice_coeff: 0.9823
# Epoch 233/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0297 - dice_coeff: 0.9821
# Epoch 234/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0287 - dice_coeff: 0.9822
# Epoch 235/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0299 - dice_coeff: 0.9819
# Epoch 236/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0307 - dice_coeff: 0.9816
# Epoch 237/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0289 - dice_coeff: 0.9825
# Epoch 238/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0296 - dice_coeff: 0.9818
# Epoch 239/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0290 - dice_coeff: 0.9818
# Epoch 240/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0301 - dice_coeff: 0.9821
# Epoch 241/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0312 - dice_coeff: 0.9812
# Epoch 242/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0283 - dice_coeff: 0.9831
# Epoch 243/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0286 - dice_coeff: 0.9824
# Epoch 244/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0273 - dice_coeff: 0.9832
# Epoch 245/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0314 - dice_coeff: 0.9814
# Epoch 246/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0293 - dice_coeff: 0.9824
# Epoch 247/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0290 - dice_coeff: 0.9822
# Epoch 248/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0291 - dice_coeff: 0.9822
# Epoch 249/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0294 - dice_coeff: 0.9823
# Epoch 250/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0279 - dice_coeff: 0.9829
# Epoch 251/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0273 - dice_coeff: 0.9835
# Epoch 252/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0295 - dice_coeff: 0.9821
# Epoch 253/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0292 - dice_coeff: 0.9820
# Epoch 254/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0288 - dice_coeff: 0.9818
# Epoch 255/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0296 - dice_coeff: 0.9814
# Epoch 256/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0290 - dice_coeff: 0.9825
# Epoch 257/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0276 - dice_coeff: 0.9830
# Epoch 258/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0294 - dice_coeff: 0.9824
# Epoch 259/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0281 - dice_coeff: 0.9829
# Epoch 260/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0275 - dice_coeff: 0.9833
# Epoch 261/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0279 - dice_coeff: 0.9828
# Epoch 262/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0274 - dice_coeff: 0.9835
# Epoch 263/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0289 - dice_coeff: 0.9824
# Epoch 264/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0276 - dice_coeff: 0.9829
# Epoch 265/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0286 - dice_coeff: 0.9827
# Epoch 266/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0278 - dice_coeff: 0.9830
# Epoch 267/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0286 - dice_coeff: 0.9826
# Epoch 268/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0277 - dice_coeff: 0.9833
# Epoch 269/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0281 - dice_coeff: 0.9829
# Epoch 270/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0281 - dice_coeff: 0.9827
# Epoch 271/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0270 - dice_coeff: 0.9833
# Epoch 272/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0284 - dice_coeff: 0.9826
# Epoch 273/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0275 - dice_coeff: 0.9834
# Epoch 274/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0275 - dice_coeff: 0.9834
# Epoch 275/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0285 - dice_coeff: 0.9830
# Epoch 276/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0274 - dice_coeff: 0.9834
# Epoch 277/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0275 - dice_coeff: 0.9833
# Epoch 278/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0279 - dice_coeff: 0.9826
# Epoch 279/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0298 - dice_coeff: 0.9823
# Epoch 280/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0274 - dice_coeff: 0.9834
# Epoch 281/400
# 32/32 [==============================] - 12s 373ms/step - loss: 0.0275 - dice_coeff: 0.9830
# Epoch 282/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0287 - dice_coeff: 0.9826
# Epoch 283/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0276 - dice_coeff: 0.9831
# Epoch 284/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0280 - dice_coeff: 0.9828
# Epoch 285/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0286 - dice_coeff: 0.9828
# Epoch 286/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0286 - dice_coeff: 0.9828
# Epoch 287/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0286 - dice_coeff: 0.9828
# Epoch 288/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0275 - dice_coeff: 0.9833
# Epoch 289/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0294 - dice_coeff: 0.9821
# Epoch 290/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0266 - dice_coeff: 0.9833
# Epoch 291/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0266 - dice_coeff: 0.9838
# Epoch 292/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0284 - dice_coeff: 0.9825
# Epoch 293/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0266 - dice_coeff: 0.9836
# Epoch 294/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0279 - dice_coeff: 0.9825
# Epoch 295/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0264 - dice_coeff: 0.9836
# Epoch 296/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0289 - dice_coeff: 0.9821
# Epoch 297/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0267 - dice_coeff: 0.9836
# Epoch 298/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0271 - dice_coeff: 0.9835
# Epoch 299/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0290 - dice_coeff: 0.9818
# Epoch 300/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0271 - dice_coeff: 0.9836
# Epoch 301/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.
400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0299 - dice_coeff: 0.9819
# Epoch 362/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0259 - dice_coeff: 0.9841
# Epoch 363/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0259 - dice_coeff: 0.9844
# Epoch 364/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0262 - dice_coeff: 0.9840
# Epoch 365/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0258 - dice_coeff: 0.9844
# Epoch 366/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0266 - dice_coeff: 0.9839
# Epoch 367/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0284 - dice_coeff: 0.9827
# Epoch 368/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0260 - dice_coeff: 0.9844
# Epoch 369/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0262 - dice_coeff: 0.9842
# Epoch 370/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0253 - dice_coeff: 0.9846
# Epoch 371/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0264 - dice_coeff: 0.9841
# Epoch 372/400
# 32/32 [==============================] - 12s 378ms/step - loss: 0.0258 - dice_coeff: 0.9841
# Epoch 373/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0264 - dice_coeff: 0.9843
# Epoch 374/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0263 - dice_coeff: 0.9838
# Epoch 375/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0255 - dice_coeff: 0.9845
# Epoch 376/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0253 - dice_coeff: 0.9846
# Epoch 377/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0255 - dice_coeff: 0.9845
# Epoch 378/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0283 - dice_coeff: 0.9837
# Epoch 379/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0258 - dice_coeff: 0.9845
# Epoch 380/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0249 - dice_coeff: 0.9848
# Epoch 381/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0284 - dice_coeff: 0.9826
# Epoch 382/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0257 - dice_coeff: 0.9842
# Epoch 383/400
# 32/32 [==============================] - 12s 380ms/step - loss: 0.0259 - dice_coeff: 0.9844
# Epoch 384/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0253 - dice_coeff: 0.9848
# Epoch 385/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0260 - dice_coeff: 0.9842
# Epoch 386/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0258 - dice_coeff: 0.9843
# Epoch 387/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0250 - dice_coeff: 0.9847
# Epoch 388/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0266 - dice_coeff: 0.9838
# Epoch 389/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0256 - dice_coeff: 0.9844
# Epoch 390/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0270 - dice_coeff: 0.9838
# Epoch 391/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0259 - dice_coeff: 0.9844
# Epoch 392/400
# 32/32 [==============================] - 12s 374ms/step - loss: 0.0248 - dice_coeff: 0.9849
# Epoch 393/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0253 - dice_coeff: 0.9842
# Epoch 394/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0260 - dice_coeff: 0.9840
# Epoch 395/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0272 - dice_coeff: 0.9831
# Epoch 396/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0248 - dice_coeff: 0.9844
# Epoch 397/400
# 32/32 [==============================] - 12s 377ms/step - loss: 0.0259 - dice_coeff: 0.9841
# Epoch 398/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0254 - dice_coeff: 0.9844
# Epoch 399/400
# 32/32 [==============================] - 12s 376ms/step - loss: 0.0272 - dice_coeff: 0.9832
# Epoch 400/400
# 32/32 [==============================] - 12s 375ms/step - loss: 0.0252 - dice_coeff: 0.9847

# %% [markdown]
# # predict

# %%
predict(
    X_test = ori_imgs, 
    model_path = "demo.hdf5", 
    out_dir = "./pred", 
    input_shape = (512, 512, 1), 
    num_classes = 1
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# (200, 512, 512, 1)

# %% [markdown]
# # confirm

# %%
pred_imgs,_ = load_Y_gray("./pred", thresh=127)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# (200, 512, 512, 1)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(2, 3, 1)
plt.imshow(ori_imgs[25][:,:,0], "gray")

plt.subplot(2, 3, 2)
plt.imshow(pred_imgs[25][:,:,0], "gray")

plt.subplot(2, 3, 3)
plt.imshow(make_mask_img(ori_imgs[25], pred_imgs[25]))

plt.subplot(2, 3, 4)
plt.imshow(ori_imgs[125][:,:,0], "gray")

plt.subplot(2, 3, 5)
plt.imshow(pred_imgs[125][:,:,0], "gray")

plt.subplot(2, 3, 6)
plt.imshow(make_mask_img(ori_imgs[125], pred_imgs[125]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
